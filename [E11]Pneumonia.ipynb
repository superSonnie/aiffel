# %%
import os, re
import random, math
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %% [markdown]
# ## 데이터 가져오기

# %%
# 데이터 로드할 때 빠르게 로드할 수 있도록하는 설정 변수
AUTOTUNE = tf.data.experimental.AUTOTUNE
# X-RAY 이미지 사이즈 변수
IMAGE_SIZE = [180, 180]

# 데이터 경로 변수
ROOT_PATH = os.path.join(os.getenv('HOME'), 'data')
TRAIN_PATH = ROOT_PATH + '/train/*/*'
VAL_PATH = ROOT_PATH + '/val/*/*'
TEST_PATH = ROOT_PATH + '/test/*/*'

# 프로젝트를 진행할 때 아래 두 변수를 변경해보세요
BATCH_SIZE = 16
EPOCHS = 25

print(ROOT_PATH)
# Out:
# /aiffel/data

# %% [markdown]
# ### validation 데이터가 너무적기 때문에 합쳐서 다시 8:2로 나눠준다.

# %%
train_filenames = tf.io.gfile.glob(TRAIN_PATH)
test_filenames = tf.io.gfile.glob(TEST_PATH)
val_filenames = tf.io.gfile.glob(VAL_PATH)

print(len(train_filenames))
print(len(test_filenames))
print(len(val_filenames))
# Out:
# 5216
# 624
# 16

# %%
# train 데이터와 validation 데이터를 모두 filenames에 담습니다
filenames = tf.io.gfile.glob(TRAIN_PATH)
filenames.extend(tf.io.gfile.glob(VAL_PATH))

# 모아진 filenames를 8:2로 나눕니다
train_size = math.floor(len(filenames)*0.8)
random.seed(8)
random.shuffle(filenames)
train_filenames = filenames[:train_size]
val_filenames = filenames[train_size:]


print(len(train_filenames))
print(len(val_filenames))
# Out:
# 4185
# 1047

# %%
# 정상 이미지와 폐렴 이미지를 구분해야 하는데
# 다행히도 파일 경로에 힌트가 있어요
print(f'Normal image path\n{filenames[0]}')
print(f'Pneumonia image path\n{filenames[2000]}')
# Out:
# Normal image path
# /aiffel/data/train/NORMAL/IM-0582-0001.jpeg
# Pneumonia image path
# /aiffel/data/train/PNEUMONIA/person313_bacteria_1457.jpeg

# %%
# 이제 파일 경로에 NORMAL이 있는지 확인하면 정상 이미지를 셀 수 있습니다.
COUNT_NORMAL = len([filename for filename in train_filenames if "NORMAL" in filename])
print(f"Normal images count in training set: {COUNT_NORMAL}")

# 파일 경로에 PNEUMONIA이 있는지 확인하면 폐렴 이미지도 셀 수 있습니다.
COUNT_PNEUMONIA = len([filename for filename in train_filenames if "PNEUMONIA" in filename])
print(f"Pneumonia images count in training set: {COUNT_PNEUMONIA}")
# Out:
# Normal images count in training set: 1072
# Pneumonia images count in training set: 3113

# %%
train_list_ds = tf.data.Dataset.from_tensor_slices(train_filenames)
val_list_ds = tf.data.Dataset.from_tensor_slices(val_filenames)

# %%
TRAIN_IMG_COUNT = tf.data.experimental.cardinality(train_list_ds).numpy()
print(f"Training images count: {TRAIN_IMG_COUNT}")

VAL_IMG_COUNT = tf.data.experimental.cardinality(val_list_ds).numpy()
print(f"Validating images count: {VAL_IMG_COUNT}")
# Out:
# Training images count: 4185
# Validating images count: 1047

# %%
# 파일 경로의 끝에서 두번째 부분을 확인하면 양성과 음성을 구분할 수 있습니다
def get_label(file_path):
    parts = tf.strings.split(file_path, os.path.sep)
    return parts[-2] == "PNEUMONIA"   # 폐렴이면 양성(True), 노말이면 음성(False)

# %%
# 이미지를 알맞은 형식으로 바꿉니다.
def decode_img(img):
    img = tf.image.decode_jpeg(img, channels=3) # 이미지를 uint8 tensor로 수정
    img = tf.image.convert_image_dtype(img, tf.float32) # float32 타입으로 수정
    img = tf.image.resize(img, IMAGE_SIZE) # 이미지 사이즈를 IMAGE_SIZE로 수정
    return img

# 이미지 파일의 경로를 입력하면 이미지와 라벨을 읽어옵니다.
def process_path(file_path):
    label = get_label(file_path) # 라벨 검출
    img = tf.io.read_file(file_path) # 이미지 읽기
    img = decode_img(img) # 이미지를 알맞은 형식으로 수정
    return img, label

# %%
train_ds = train_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
val_ds = val_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)

# %%
for image, label in train_ds.take(1):
    print("Image shape: ", image.numpy().shape)
    print("Label: ", label.numpy())
# Out:
# Image shape:  (180, 180, 3)
# Label:  False

# %%
test_list_ds = tf.data.Dataset.list_files(TEST_PATH)
TEST_IMAGE_COUNT = tf.data.experimental.cardinality(test_list_ds).numpy()
test_ds = test_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
test_ds = test_ds.batch(BATCH_SIZE)

print(TEST_IMAGE_COUNT)
# Out:
# 624

# %%
def prepare_for_training(ds, shuffle_buffer_size=1000):
    ds = ds.shuffle(buffer_size=shuffle_buffer_size)
    ds = ds.repeat()
    ds = ds.batch(BATCH_SIZE)
    ds = ds.prefetch(buffer_size=AUTOTUNE)
    return ds

train_ds = prepare_for_training(train_ds)
val_ds = prepare_for_training(val_ds)

# %% [markdown]
# ## 데이터 시각화

# %%
# 이미지 배치를 입력하면 여러장의 이미지를 보여줍니다.
def show_batch(image_batch, label_batch):
    plt.figure(figsize=(10,10))
    for n in range(BATCH_SIZE):
        ax = plt.subplot(5,math.ceil(BATCH_SIZE/5),n+1)
        plt.imshow(image_batch[n])
        if label_batch[n]:
            plt.title("PNEUMONIA")
        else:
            plt.title("NORMAL")
        plt.axis("off")


image_batch, label_batch = next(iter(train_ds))
show_batch(image_batch.numpy(), label_batch.numpy())

# %% [markdown]
# ## CNN 모델링

# %%
def conv_block(filters):
    block = tf.keras.Sequential([
        tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.MaxPool2D()
    ])
    
    return block

# %%
def dense_block(units, dropout_rate):
    block = tf.keras.Sequential([
        tf.keras.layers.Dense(units, activation='relu'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(dropout_rate)
    ])
    
    return block

# %%
def build_model():
    model = tf.keras.Sequential([
        tf.keras.Input(shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)),
        
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.MaxPool2D(),
        
        conv_block(32),
        conv_block(64),
        
        conv_block(128),
        tf.keras.layers.Dropout(0.2),
        
        conv_block(256),
        tf.keras.layers.Dropout(0.2),
        
        tf.keras.layers.Flatten(),
        dense_block(512, 0.7),
        dense_block(128, 0.5),
        dense_block(64, 0.3),
        
        tf.keras.layers.Dense(1, activation='sigmoid')
    ])
    
    return model

# %% [markdown]
# ## 데이터 Imbalance 해결

# %%
weight_for_0 = (1 / COUNT_NORMAL)*(TRAIN_IMG_COUNT)/2.0 
weight_for_1 = (1 / COUNT_PNEUMONIA)*(TRAIN_IMG_COUNT)/2.0

class_weight = {0: weight_for_0, 1: weight_for_1}

print('Weight for NORMAL: {:.2f}'.format(weight_for_0))
print('Weight for PNEUMONIA: {:.2f}'.format(weight_for_1))
# Out:
# Weight for NORMAL: 1.95
# Weight for PNEUMONIA: 0.67

# %% [markdown]
# ## 모델 훈련

# %%
with tf.device('/GPU:0'):
    model = build_model()

    METRICS = [
        'accuracy',
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall')
    ]
    
    model.compile(
        optimizer='adam',
        loss='binary_crossentropy',
        metrics=METRICS
    )

# %%
with tf.device('/GPU:0'):
    history = model.fit(
        train_ds,
        steps_per_epoch=TRAIN_IMG_COUNT // BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=val_ds,
        validation_steps=VAL_IMG_COUNT // BATCH_SIZE,
        class_weight=class_weight,
    )
# Out:
# Epoch 1/25
# 261/261 [==============================] - 42s 133ms/step - loss: 0.5106 - accuracy: 0.7487 - precision: 0.9257 - recall: 0.7192 - val_loss: 0.6708 - val_accuracy: 0.7346 - val_precision: 0.7346 - val_recall: 1.0000
# Epoch 2/25
# 261/261 [==============================] - 34s 131ms/step - loss: 0.2452 - accuracy: 0.9025 - precision: 0.9739 - recall: 0.8939 - val_loss: 1.2103 - val_accuracy: 0.7356 - val_precision: 0.7356 - val_recall: 1.0000
# Epoch 3/25
# 261/261 [==============================] - 34s 130ms/step - loss: 0.1840 - accuracy: 0.9337 - precision: 0.9774 - recall: 0.9330 - val_loss: 0.6374 - val_accuracy: 0.7692 - val_precision: 0.7610 - val_recall: 1.0000
# Epoch 4/25
# 261/261 [==============================] - 34s 131ms/step - loss: 0.1684 - accuracy: 0.9395 - precision: 0.9845 - recall: 0.9334 - val_loss: 0.1125 - val_accuracy: 0.9558 - val_precision: 0.9891 - val_recall: 0.9503
# Epoch 5/25
# 261/261 [==============================] - 34s 130ms/step - loss: 0.1639 - accuracy: 0.9377 - precision: 0.9829 - recall: 0.9331 - val_loss: 0.1138 - val_accuracy: 0.9567 - val_precision: 0.9477 - val_recall: 0.9961
# Epoch 6/25
# 261/261 [==============================] - 34s 130ms/step - loss: 0.1503 - accuracy: 0.9423 - precision: 0.9860 - recall: 0.9360 - val_loss: 0.1612 - val_accuracy: 0.9346 - val_precision: 0.9916 - val_recall: 0.9192
# Epoch 7/25
# 261/261 [==============================] - 34s 130ms/step - loss: 0.1631 - accuracy: 0.9350 - precision: 0.9840 - recall: 0.9291 - val_loss: 0.0831 - val_accuracy: 0.9663 - val_precision: 0.9893 - val_recall: 0.9647
# Epoch 8/25
# 261/261 [==============================] - 34s 131ms/step - loss: 0.1318 - accuracy: 0.9506 - precision: 0.9878 - recall: 0.9461 - val_loss: 0.2409 - val_accuracy: 0.9106 - val_precision: 0.9956 - val_recall: 0.8825
# Epoch 9/25
# 261/261 [==============================] - 34s 131ms/step - loss: 0.1611 - accuracy: 0.9406 - precision: 0.9848 - recall: 0.9346 - val_loss: 0.0706 - val_accuracy: 0.9654 - val_precision: 0.9959 - val_recall: 0.9569
# Epoch 10/25
# 261/261 [==============================] - 34s 131ms/step - loss: 0.1434 - accuracy: 0.9470 - precision: 0.9856 - recall: 0.9439 - val_loss: 0.2120 - val_accuracy: 0.9173 - val_precision: 0.9985 - val_recall: 0.8889
# Epoch 11/25
# 261/261 [==============================] - 34s 131ms/step - loss: 0.1184 - accuracy: 0.9555 - precision: 0.9893 - recall: 0.9500 - val_loss: 0.0541 - val_accuracy: 0.9817 - val_precision: 0.9870 - val_recall: 0.9883
# Epoch 12/25
# 261/261 [==============================] - 34s 131ms/step - loss: 0.1096 - accuracy: 0.9628 - precision: 0.9853 - recall: 0.9645 - val_loss: 0.1155 - val_accuracy: 0.9558 - val_precision: 0.9800 - val_recall: 0.9595
# Epoch 13/25
# 261/261 [==============================] - 34s 131ms/step - loss: 0.1113 - accuracy: 0.9559 - precision: 0.9907 - recall: 0.9499 - val_loss: 0.0622 - val_accuracy: 0.9769 - val_precision: 0.9831 - val_recall: 0.9857
# Epoch 14/25
# 261/261 [==============================] - 34s 131ms/step - loss: 0.1171 - accuracy: 0.9621 - precision: 0.9862 - recall: 0.9623 - val_loss: 0.0610 - val_accuracy: 0.9779 - val_precision: 0.9947 - val_recall: 0.9752
# Epoch 15/25
# 261/261 [==============================] - 34s 130ms/step - loss: 0.0917 - accuracy: 0.9702 - precision: 0.9923 - recall: 0.9677 - val_loss: 0.0775 - val_accuracy: 0.9702 - val_precision: 0.9986 - val_recall: 0.9607
# Epoch 16/25
# 261/261 [==============================] - 34s 130ms/step - loss: 0.0852 - accuracy: 0.9702 - precision: 0.9934 - recall: 0.9661 - val_loss: 0.1183 - val_accuracy: 0.9481 - val_precision: 0.9972 - val_recall: 0.9320
# Epoch 17/25
# 261/261 [==============================] - 34s 130ms/step - loss: 0.1007 - accuracy: 0.9632 - precision: 0.9899 - recall: 0.9594 - val_loss: 0.1666 - val_accuracy: 0.9375 - val_precision: 1.0000 - val_recall: 0.9149
# Epoch 18/25
# 261/261 [==============================] - 34s 131ms/step - loss: 0.0690 - accuracy: 0.9758 - precision: 0.9957 - recall: 0.9716 - val_loss: 0.1193 - val_accuracy: 0.9510 - val_precision: 1.0000 - val_recall: 0.9334
# Epoch 19/25
# 261/261 [==============================] - 34s 131ms/step - loss: 0.0861 - accuracy: 0.9669 - precision: 0.9893 - recall: 0.9659 - val_loss: 0.0784 - val_accuracy: 0.9702 - val_precision: 0.9842 - val_recall: 0.9752
# Epoch 20/25
# 261/261 [==============================] - 34s 130ms/step - loss: 0.0881 - accuracy: 0.9688 - precision: 0.9910 - recall: 0.9667 - val_loss: 0.0737 - val_accuracy: 0.9827 - val_precision: 0.9908 - val_recall: 0.9856
# Epoch 21/25
# 261/261 [==============================] - 34s 131ms/step - loss: 0.0692 - accuracy: 0.9749 - precision: 0.9914 - recall: 0.9744 - val_loss: 0.5083 - val_accuracy: 0.8625 - val_precision: 0.9237 - val_recall: 0.8863
# Epoch 22/25
# 261/261 [==============================] - 34s 132ms/step - loss: 0.0718 - accuracy: 0.9771 - precision: 0.9928 - recall: 0.9758 - val_loss: 0.0816 - val_accuracy: 0.9673 - val_precision: 0.9959 - val_recall: 0.9596
# Epoch 23/25
# 261/261 [==============================] - 34s 132ms/step - loss: 0.0708 - accuracy: 0.9743 - precision: 0.9944 - recall: 0.9710 - val_loss: 0.0867 - val_accuracy: 0.9712 - val_precision: 0.9635 - val_recall: 0.9987
# Epoch 24/25
# 261/261 [==============================] - 34s 131ms/step - loss: 0.0600 - accuracy: 0.9800 - precision: 0.9947 - recall: 0.9778 - val_loss: 0.0632 - val_accuracy: 0.9837 - val_precision: 0.9832 - val_recall: 0.9948
# Epoch 25/25
# 261/261 [==============================] - 34s 131ms/step - loss: 0.0361 - accuracy: 0.9879 - precision: 0.9958 - recall: 0.9879 - val_loss: 0.3142 - val_accuracy: 0.8827 - val_precision: 0.9984 - val_recall: 0.8418

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['precision', 'recall', 'accuracy', 'loss']):
    ax[i].plot(history.history[met])
    ax[i].plot(history.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %%
loss, accuracy, precision, recall = model.evaluate(test_ds)
print(f'Loss: {loss},\nAccuracy: {accuracy},\nPrecision: {precision},\nRecall: {recall}')
# Out:
# 39/39 [==============================] - 3s 74ms/step - loss: 0.5056 - accuracy: 0.8526 - precision: 0.8763 - recall: 0.8897
# Loss: 0.5056019425392151,
# Accuracy: 0.8525640964508057,
# Precision: 0.8762626051902771,
# Recall: 0.8897435665130615

# %% [markdown]
# # 회고
#
# 불균형한 데이터를 나누는 방법에 대해 알게 되어 좋았다. 이번 두시 데이터 풀잎에서 하는 캐글에서도 데이터가 불균형한데 이에 적용해볼 수 있을 것 같다. 모델을 훈련하는 데 에 있어서는 크게 건들진 않았지만, 가위바위보때 썼던 데이터 증강법이나, 하이퍼 파라미터를 약간씩 건들면서 조정해볼 수 있을 것 같았다. 가위바위보때 느꼈듯이 데이터가 많으면 자연스레 정확도가 확보되기 때문에, 다음엔 데이터증강까지해서 더 높은 정확도를 확보할 수 있도록 해보아야겠다.
